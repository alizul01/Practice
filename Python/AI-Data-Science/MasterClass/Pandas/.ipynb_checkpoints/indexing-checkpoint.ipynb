# %%
import pandas as pd

# %%
data = pd.read_csv('kapal_titanic.csv')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataUmur = data['age']
print(dataUmur.head(), type(dataUmur))
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64 <class 'pandas.core.series.Series'>

# %%
data[['age', 'fare']]
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# # Apa itu "Dot Notation"?

# %%
data.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
data.age.equals(data['age'])
# Out:
# True

# %%
data[['age']]
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %% [markdown]
# # iloc
#
# ## .iloc[baris, kolom]

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
data.iloc[:, 3:4]
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
data.iloc[-1:-10:-1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 883         0       2    male  28.0      0      0  10.5000        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN

# %%
data.iloc[0:7, [1, 3, 6]]
# Out:
#    pclass   age     fare
# 0       3  22.0   7.2500
# 1       1  38.0  71.2833
# 2       3  26.0   7.9250
# 3       1  35.0  53.1000
# 4       3  35.0   8.0500
# 5       3   NaN   8.4583
# 6       1  54.0  51.8625

# %% [markdown]
# # loc
#
# ### .loc['nama baris', 'nama kolom']

# %%
data_baru = pd.read_csv('kapal_titanic.csv', index_col="embarked")

# %%
data_baru
# Out:
#           survived  pclass     sex   age  sibsp  parch     fare deck
# embarked
# S                0       3    male  22.0      1      0   7.2500  NaN
# C                1       1  female  38.0      1      0  71.2833    C
# S                1       3  female  26.0      0      0   7.9250  NaN
# S                1       1  female  35.0      1      0  53.1000    C
# S                0       3    male  35.0      0      0   8.0500  NaN
# ...            ...     ...     ...   ...    ...    ...      ...  ...
# S                0       2    male  27.0      0      0  13.0000  NaN
# S                1       1  female  19.0      0      0  30.0000    B
# S                0       3  female   NaN      1      2  23.4500  NaN
# C                1       1    male  26.0      0      0  30.0000    C
# Q                0       3    male  32.0      0      0   7.7500  NaN
#
# [891 rows x 8 columns]

# %%
data_baru.loc[['S', 'Q'], ['age', 'fare']]
# Out:
#            age     fare
# embarked
# S         22.0   7.2500
# S         26.0   7.9250
# S         35.0  53.1000
# S         35.0   8.0500
# S         54.0  51.8625
# ...        ...      ...
# Q          NaN   7.7500
# Q          NaN   6.9500
# Q          NaN   7.7500
# Q         39.0  29.1250
# Q         32.0   7.7500
#
# [721 rows x 2 columns]

# %%
pd.options.display.min_rows = 891
pd.options.display.max_rows = 891

# %%
data_baru
# Out:
#           survived  pclass     sex    age  sibsp  parch      fare deck
# embarked
# S                0       3    male  22.00      1      0    7.2500  NaN
# C                1       1  female  38.00      1      0   71.2833    C
# S                1       3  female  26.00      0      0    7.9250  NaN
# S                1       1  female  35.00      1      0   53.1000    C
# S                0       3    male  35.00      0      0    8.0500  NaN
# Q                0       3    male    NaN      0      0    8.4583  NaN
# S                0       1    male  54.00      0      0   51.8625    E
# S                0       3    male   2.00      3      1   21.0750  NaN
# S                1       3  female  27.00      0      2   11.1333  NaN
# C                1       2  female  14.00      1      0   30.0708  NaN
# S                1       3  female   4.00      1      1   16.7000    G
# S                1       1  female  58.00      0      0   26.5500    C
# ...

# %%
S
