# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(100)

# %%
data = pd.DataFrame(np.random.randn(3,5), ['A', 'B', 'C'], ['Satu', 'Dua', 'Tiga', 'Empat', 'Lima'])

# %%
data
# Out:
#        Satu       Dua      Tiga     Empat      Lima
# A -1.749765  0.342680  1.153036 -0.252436  0.981321
# B  0.514219  0.221180 -1.070043 -0.189496  0.255001
# C -0.458027  0.435163 -0.583595  0.816847  0.672721

# %%
type(data['Dua'])
# Out:
# pandas.core.series.Series

# %%
# Iloc loc

data['Enam'] = data['Empat'] + data['Lima']

# %%
data
# Out:
#        Satu       Dua      Tiga     Empat      Lima      Enam
# A -1.749765  0.342680  1.153036 -0.252436  0.981321  0.728885
# B  0.514219  0.221180 -1.070043 -0.189496  0.255001  0.065506
# C -0.458027  0.435163 -0.583595  0.816847  0.672721  1.489568

# %%
data.drop('Enam', axis=1, inplace=True)

# %%
data
# Out:
#        Satu       Dua      Tiga     Empat      Lima
# A -1.749765  0.342680  1.153036 -0.252436  0.981321
# B  0.514219  0.221180 -1.070043 -0.189496  0.255001
# C -0.458027  0.435163 -0.583595  0.816847  0.672721

# %%
data.drop('B', axis=0, inplace=True)

# %%
data
# Out:
#        Satu       Dua      Tiga     Empat      Lima
# A -1.749765  0.342680  1.153036 -0.252436  0.981321
# C -0.458027  0.435163 -0.583595  0.816847  0.672721

# %%
data.shape
# Out:
# (2, 5)

# %%
data < 0
# Out:
#    Satu    Dua   Tiga  Empat   Lima
# A  True  False  False   True  False
# C  True  False   True  False  False

# %%
data[data < 0]
# Out:
#        Satu  Dua      Tiga     Empat  Lima
# A -1.749765  NaN       NaN -0.252436   NaN
# C -0.458027  NaN -0.583595       NaN   NaN

# %%
data = pd.DataFrame(np.random.randn(3,5), ['A', 'B', 'C'], ['Satu', 'Dua', 'Tiga', 'Empat', 'Lima'])

# %%
data[data['Lima'] > 0 ]
# Out:
#        Satu       Dua      Tiga     Empat      Lima
# B  1.618982  1.541605 -0.251879 -0.842436  0.184519
# C  0.937082  0.731000  1.361556 -0.326238  0.055676

# %% [markdown]
# # Kapal Titanic

# %%
import numpy as np
import pandas as pd

# %%
dataTitanic = pd.read_csv('kapal_titanic.csv')
dataTitanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
age = dataTitanic['age']
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
age.count()
# Out:
# 714

# %%
age.sum()
# Out:
# 21205.17

# %%
sum(age)
# Out:
# nan

# %%
age_bersih = age.dropna()

# %%
age_bersih
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 714, dtype: float64

# %%
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
age_bersih[890]
# Out:
# 32.0

# %%
age_bersih
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 714, dtype: float64

# %% [markdown]
# ### Kalo ada data kosong diisi dengan data rata-rata

# %%
dataBaru2 = dataTitanic
dataBaru2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataBaru2.age.fillna(value=dataBaru2.age.mean(), inplace=True)

# %%
fare = dataTitanic['fare']

# %%
dataBaru2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.000000      1      0   7.2500        S  NaN
# 1           1       1  female  38.000000      1      0  71.2833        C    C
# 2           1       3  female  26.000000      0      0   7.9250        S  NaN
# 3           1       1  female  35.000000      1      0  53.1000        S    C
# 4           0       3    male  35.000000      0      0   8.0500        S  NaN
# ..        ...     ...     ...        ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.000000      0      0  13.0000        S  NaN
# 887         1       1  female  19.000000      0      0  30.0000        S    B
# 888         0       3  female  29.699118      1      2  23.4500        S  NaN
# 889         1       1    male  26.000000      0      0  30.0000        C    C
# 890         0       3    male  32.000000      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataBaru2.age.values
# Out:
# array([22.        , 38.        , 26.        , 35.        , 35.        ,
#        29.69911765, 54.        ,  2.        , 27.        , 14.        ,
#         4.        , 58.        , 20.        , 39.        , 14.        ,
#        55.        ,  2.        , 29.69911765, 31.        , 29.69911765,
#        35.        , 34.        , 15.        , 28.        ,  8.        ,
#        38.        , 29.69911765, 19.        , 29.69911765, 29.69911765,
#        40.        , 29.69911765, 29.69911765, 66.        , 28.        ,
#        42.        , 29.69911765, 21.        , 18.        , 14.        ,
#        40.        , 27.        , 29.69911765,  3.        , 19.        ,
#        29.69911765, 29.69911765, 29.69911765, 29.69911765, 18.        ,
#         7.        , 21.        , 49.        , 29.        , 65.        ,
#        29.69911765, 21.        , 28.5       ,  5.        , 11.        ,
#        22.        , 38.        , 45.        ,  4.        , 29.69911765,
# ...
